# %%
import sys     ###motion_test_header
sys.path.append('../scripts/')
from robot import *

# %%
world = World(40.0, 0.1)  

initial_pose = np.array([0, 0, 0]).T
robots = []

for i in range(100):
    r = Robot(initial_pose, sensor=None, agent=Agent(0.1, 0.0)) 
    world.append(r)
    robots.append(r)

world.draw()
# Out:
# <img src="data:image/png;base64,..." width="400">

# %%
import pandas as pd ###motion_test_stats（下のセルまで。データは上の5行程度を掲載）
poses = pd.DataFrame([ [math.sqrt(r.pose[0]**2 + r.pose[1]**2), r.pose[2]] for r in robots], columns=['r', 'theta'])
poses
# Out:
#            r     theta
# 0   4.139644 -0.232683
# 1   3.654605 -0.032148
# 2   4.195843 -0.171538
# 3   3.307442 -0.199113
# 4   4.365360 -0.294505
# 5   4.454770  0.437175
# 6   3.622072 -0.264031
# 7   3.687211 -0.012295
# 8   4.600229 -0.131052
# 9   3.508852  0.337135
# 10  4.429170  0.011661
# 11  3.251079  0.410670
# 12  3.414544 -0.086313
# 13  3.793292  0.189415
# 14  4.337097  0.198976
# 15  3.928332  0.081943
# 16  4.787906 -0.015330
# 17  3.965885  0.225464
# 18  3.639209 -0.275031
# 19  3.414187  0.159490
# 20  3.886678  0.299303
# 21  4.205185  0.268838
# 22  4.616282 -0.135271
# 23  3.989071 -0.120355
# 24  4.209926  0.126586
# 25  4.638187  0.061094
# 26  4.020109 -0.112053
# 27  4.456769  0.100949
# 28  3.254725  0.366395
# 29  4.536302  0.030802
# ..       ...       ...
# 70  4.212036  0.270949
# 71  3.732389 -0.000654
# 72  3.985110  0.435020
# 73  4.061774  0.296101
# 74  4.501792 -0.403620
# 75  4.073521 -0.264254
# 76  4.147428  0.469652
# 77  3.995409  0.274952
# 78  3.578801 -0.066661
# 79  3.490465 -0.149795
# 80  3.496225 -0.193252
# 81  4.265018 -0.059300
# 82  3.371489 -0.092487
# 83  3.600345  0.059940
# 84  3.996603  0.043109
# 85  4.118371  0.091919
# 86  4.104537 -0.050530
# 87  4.345458 -0.086066
# 88  3.439285  0.005764
# 89  3.698259 -0.339504
# 90  4.554214  0.168764
# 91  3.898210  0.094254
# 92  4.379996 -0.162880
# 93  3.875796  0.223705
# 94  4.623358 -0.063596
# 95  3.733230  0.281610
# 96  4.055215 -0.223867
# 97  4.068974 -0.137247
# 98  3.718429 -0.559361
# 99  4.373495  0.037524
#
# [100 rows x 2 columns]

# %%
poses.mean()
# Out:
# r        3.996594
# theta    0.008087
# dtype: float64

# %%
poses.var()
# Out:
# r        0.152550
# theta    0.054597
# dtype: float64

# %%
poses.std()
# Out:
# r        0.390576
# theta    0.233660
# dtype: float64

# %%
math.sqrt(0.152550/3.996594)
# Out:
# 0.19537144560169395
