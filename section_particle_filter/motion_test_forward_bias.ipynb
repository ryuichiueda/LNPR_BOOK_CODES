# %%
import sys 
sys.path.append('../scripts/')
from robot import *

# %%
world = World(40.0, 0.1)      ###motion_test_forward_bias

initial_pose = np.array([0, 0, 0]).T
robots = []

for i in range(100):
    r = Robot(initial_pose, sensor=None, agent=Agent(0.1, 0.0))  #ここで生成されるロボットは異なるバイアスを持つ
    world.append(r)
    robots.append(r)

world.draw()
# Out:
# <img src="data:image/png;base64,..." width="400">

# %%
import pandas as pd ###motion_test_stats_bias
poses = pd.DataFrame([ [math.sqrt(r.pose[0]**2 + r.pose[1]**2), r.pose[2]] for r in robots], columns=['r', 'theta'])
poses.transpose()
# Out:
#              0         1         2         3         4         5         6   \
# r      4.194638  3.635900  3.322928  4.763659  3.491149  3.205507  4.231399
# theta  0.130801  0.115078 -0.261154  0.217645  0.230722  0.631595  0.414790
#
#              7         8         9     ...          90        91        92  \
# r      3.501991  4.086790  4.316829    ...     4.01756  3.517176  4.126948
# theta  0.544342  0.234496 -0.134852    ...     0.01041  0.013739 -0.053750
#
#              93        94        95        96        97        98        99
# r      4.267420  3.717264  3.995135  3.919313  4.016172  4.129601  4.376073
# theta -0.098055 -0.246075  0.259290  0.270943 -0.380466 -0.522060  0.113459
#
# [2 rows x 100 columns]

# %%
print(poses["r"].var()) 
print(poses["r"].mean())
math.sqrt(poses["r"].var()/poses["r"].mean())
# Out:
# 0.13835789089364178
# 3.9651024185095434
# 0.18679909237212927
