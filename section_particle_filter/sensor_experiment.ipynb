# %%
import sys  ###sensor_experiment
sys.path.append('../scripts/')
from robot import *

m = Map()
m.append_landmark(Landmark(1,0))

distance = []
direction = []

for i in range(1000):
    c = Camera(m)    #バイアスの影響も考慮するため毎回カメラを新規作成
    d = c.data(np.array([0.0, 0.0, 0.0]).T)
    if len(d) > 0:
        distance.append(d[0][0][0])
        direction.append(d[0][0][1])
        
import pandas as pd
df = pd.DataFrame()
df["distance"] = distance
df["direction"] = direction
df
# Out:
#      distance  direction
# 0    1.014872  -0.073061
# 1    0.811171   0.040348
# 2    0.784988   0.017991
# 3    1.119175   0.005638
# 4    1.262065   0.022443
# 5    0.919015  -0.036594
# 6    0.873110   0.027826
# 7    1.070208  -0.010506
# 8    1.136828   0.008138
# 9    0.945939  -0.105008
# 10   0.987615  -0.006331
# 11   1.205463   0.052046
# 12   0.958843   0.014954
# 13   1.002921   0.017638
# 14   0.808036   0.006072
# 15   0.885812   0.009431
# 16   0.885897  -0.051119
# 17   0.896757   0.039138
# 18   0.987803   0.091702
# 19   0.986813   0.018123
# 20   0.823929   0.017358
# 21   1.359914  -0.019783
# 22   1.052995   0.014265
# 23   0.941338  -0.053790
# 24   1.040544   0.010090
# 25   0.992751  -0.012571
# 26   1.228835   0.063801
# 27   1.317062  -0.027550
# 28   1.105235  -0.006007
# 29   1.066970  -0.030088
# ..        ...        ...
# 874  0.988875  -0.060102
# 875  1.026914   0.037079
# 876  1.237129  -0.033020
# 877  0.942776  -0.087547
# 878  1.079147   0.036347
# 879  0.935685  -0.051473
# 880  0.835867   0.024130
# 881  0.984819   0.011195
# 882  1.059956   0.050766
# 883  1.037110  -0.056266
# 884  1.041138  -0.022192
# 885  0.974711  -0.042435
# 886  1.005050  -0.005776
# 887  0.931255  -0.015503
# 888  1.257316  -0.055352
# 889  0.989798  -0.004721
# 890  0.860510   0.013746
# 891  1.094758  -0.036899
# 892  0.763186   0.029647
# 893  0.891375   0.077918
# 894  0.793538  -0.012601
# 895  0.871301   0.041858
# 896  1.037124   0.039784
# 897  0.630603   0.019173
# 898  0.925366   0.014392
# 899  0.679947  -0.074731
# 900  0.903961  -0.011128
# 901  1.189029  -0.039368
# 902  0.922673   0.016254
# 903  1.103565   0.019651
#
# [904 rows x 2 columns]

# %%
df.std() ###sensor_exp_res　(下のmeanも)
# Out:
# distance     0.143729
# direction    0.046686
# dtype: float64

# %%
df.mean()        #平均値は使わないが念のため
# Out:
# distance     0.999818
# direction   -0.001492
# dtype: float64
