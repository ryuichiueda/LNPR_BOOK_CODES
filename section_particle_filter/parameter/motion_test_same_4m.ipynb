# %%
import sys              ###motion_test_header
sys.path.append('../scripts/')
from robot import *

# %%
import copy

world = World(40.0, 0.1)                    ###motion_test_linear

initial_pose = np.array([0, 0, 0]).T
linear = Agent(0.1, 0.0) 
robots = []
r = Robot(initial_pose, sensor=None, agent=linear) 
for i in range(100):
    copy_r = copy.copy(r)
    world.append(copy_r)
    robots.append(copy_r)

### アニメーション実行 ###
world.draw()
# Out:
# <img src="data:image/png;base64,..." width="400">

# %%
import pandas as pd ###motion_test_stats（下のセルまで。データは上の5行程度を掲載）
poses = pd.DataFrame([ [math.sqrt(r.pose[0]**2 + r.pose[1]**2), r.pose[2]] for r in robots], columns=['r', 'theta'])
poses
# Out:
#            r     theta
# 0   4.330392 -0.330317
# 1   4.346338  0.198003
# 2   4.331944 -0.073599
# 3   4.163919 -0.728735
# 4   4.354720  0.104282
# 5   4.336877  0.355362
# 6   4.348494 -0.101065
# 7   4.348863 -0.024653
# 8   4.333691  0.344927
# 9   4.344112 -0.138283
# 10  4.343374  0.104925
# 11  4.330376  0.039325
# 12  4.350637 -0.009032
# 13  4.350274  0.164266
# 14  4.334360 -0.081079
# 15  4.343479  0.049355
# 16  4.339602 -0.260088
# 17  4.354138  0.147466
# 18  4.337892 -0.264781
# 19  4.338693 -0.252426
# 20  4.353270 -0.054017
# 21  4.341586  0.267989
# 22  4.337745 -0.033556
# 23  4.338658 -0.170440
# 24  4.325385 -0.362933
# 25  4.350395 -0.112898
# 26  4.351184 -0.129023
# 27  4.341451 -0.379759
# 28  4.323262  0.250725
# 29  4.354154 -0.091962
# ..       ...       ...
# 70  4.352142  0.077626
# 71  4.320538  0.449568
# 72  4.342115 -0.085819
# 73  4.350477  0.133364
# 74  4.345144  0.169390
# 75  4.297576  0.565001
# 76  4.350786 -0.131902
# 77  4.345544  0.211510
# 78  4.347284 -0.160479
# 79  4.355487 -0.242204
# 80  4.326345 -0.434951
# 81  4.339204  0.245397
# 82  4.349676 -0.107691
# 83  4.341427  0.241324
# 84  4.342420 -0.213270
# 85  4.356464  0.118437
# 86  4.261635 -0.566563
# 87  4.343369 -0.150198
# 88  4.339024  0.428935
# 89  4.339154 -0.234549
# 90  4.352325 -0.156433
# 91  4.331936  0.098767
# 92  4.331726 -0.055338
# 93  4.342479 -0.361943
# 94  4.333686  0.301176
# 95  4.349896 -0.073723
# 96  4.340726  0.337272
# 97  4.333713  0.024304
# 98  4.328879 -0.019800
# 99  4.322935  0.400333
#
# [100 rows x 2 columns]

# %%
poses.mean()
# Out:
# r        4.335452
# theta    0.015377
# dtype: float64

# %%
poses.var()
# Out:
# r        0.000654
# theta    0.070450
# dtype: float64

# %%
poses.std()
# Out:
# r        0.025576
# theta    0.265424
# dtype: float64
