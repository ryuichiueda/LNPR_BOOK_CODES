# %%
import sys              ###motion_test_header
sys.path.append('../scripts/')
from robot import *

# %%
import copy

world = World(20.0, 0.1)                    ###motion_test_linear

initial_pose = np.array([0, 0, 0]).T
linear = Agent(0.1, 0.0) 
robots = []
r = Robot(initial_pose, sensor=None, agent=linear) 
for i in range(100):
    copy_r = copy.copy(r)
    world.append(copy_r)
    robots.append(copy_r)

### アニメーション実行 ###
world.draw()
# Out:
# <img src="data:image/png;base64,..." width="400">

# %%
import pandas as pd ###motion_test_stats（下のセルまで。データは上の5行程度を掲載）
poses = pd.DataFrame([ [math.sqrt(r.pose[0]**2 + r.pose[1]**2), r.pose[2]] for r in robots], columns=['r', 'theta'])
poses
# Out:
#            r     theta
# 0   2.189963 -0.098206
# 1   2.194183  0.359857
# 2   2.200136  0.097459
# 3   2.197312 -0.144569
# 4   2.197702  0.053294
# 5   2.198583  0.100073
# 6   2.197445 -0.047644
# 7   2.197746  0.215903
# 8   2.198790  0.147498
# 9   2.195849 -0.159324
# 10  2.200369  0.094872
# 11  2.191949  0.259653
# 12  2.198005 -0.147115
# 13  2.199598 -0.083550
# 14  2.199296 -0.121913
# 15  2.199120 -0.036826
# 16  2.201167 -0.026550
# 17  2.198863 -0.121916
# 18  2.200085  0.072308
# 19  2.198176  0.239358
# 20  2.190420  0.266522
# 21  2.200475 -0.054686
# 22  2.200883  0.078179
# 23  2.190433 -0.112593
# 24  2.199599 -0.126455
# 25  2.201558 -0.004809
# 26  2.199172 -0.134527
# 27  2.200466 -0.066559
# 28  2.198371 -0.099722
# 29  2.194024 -0.156262
# ..       ...       ...
# 70  2.199265 -0.205628
# 71  2.199030 -0.070131
# 72  2.198150  0.013638
# 73  2.192632  0.293439
# 74  2.195084  0.174510
# 75  2.193873  0.283876
# 76  2.198973  0.044330
# 77  2.189282 -0.242633
# 78  2.200394  0.083249
# 79  2.199928  0.053336
# 80  2.192112 -0.284374
# 81  2.200993 -0.070083
# 82  2.198510  0.103487
# 83  2.189075  0.257999
# 84  2.200678 -0.068510
# 85  2.201103  0.047990
# 86  2.174268  0.582341
# 87  2.193449  0.007572
# 88  2.199797 -0.002547
# 89  2.199960  0.167163
# 90  2.181769 -0.279123
# 91  2.197578  0.284695
# 92  2.199315  0.073945
# 93  2.197040 -0.069693
# 94  2.199749  0.107962
# 95  2.200837  0.007681
# 96  2.197141  0.193435
# 97  2.195075  0.039560
# 98  2.198585 -0.056664
# 99  2.195042 -0.064005
#
# [100 rows x 2 columns]

# %%
poses.mean()
# Out:
# r        2.196436
# theta    0.025627
# dtype: float64

# %%
poses.var()
# Out:
# r        0.000024
# theta    0.031351
# dtype: float64

# %%
poses.std()
# Out:
# r        0.004907
# theta    0.177062
# dtype: float64
