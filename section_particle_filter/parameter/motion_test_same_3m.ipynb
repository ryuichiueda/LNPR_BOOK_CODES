# %%
import sys              ###motion_test_header
sys.path.append('../scripts/')
from robot import *

# %%
import copy

world = World(30.0, 0.1)                    ###motion_test_linear

initial_pose = np.array([0, 0, 0]).T
linear = Agent(0.1, 0.0) 
robots = []
r = Robot(initial_pose, sensor=None, agent=linear) 
for i in range(100):
    copy_r = copy.copy(r)
    world.append(copy_r)
    robots.append(copy_r)

### アニメーション実行 ###
world.draw()
# Out:
# <img src="data:image/png;base64,..." width="400">

# %%
import pandas as pd ###motion_test_stats（下のセルまで。データは上の5行程度を掲載）
poses = pd.DataFrame([ [math.sqrt(r.pose[0]**2 + r.pose[1]**2), r.pose[2]] for r in robots], columns=['r', 'theta'])
poses
# Out:
#            r     theta
# 0   3.128749  0.163931
# 1   3.097213  0.426346
# 2   3.127902 -0.122603
# 3   3.124393  0.173736
# 4   3.130848 -0.016282
# 5   3.127116 -0.143285
# 6   3.124095  0.199584
# 7   3.126118 -0.179768
# 8   3.127345  0.154733
# 9   3.124807  0.162736
# 10  3.116568  0.009009
# 11  3.128429 -0.072920
# 12  3.118653 -0.047434
# 13  3.129977 -0.044492
# 14  3.128655  0.143107
# 15  3.127117  0.128341
# 16  3.122675  0.283806
# 17  3.120856  0.206215
# 18  3.123620  0.219517
# 19  3.118521 -0.205664
# 20  3.107365 -0.266901
# 21  3.122884 -0.091825
# 22  3.123146  0.166998
# 23  3.131480  0.001888
# 24  3.118854  0.321763
# 25  3.118728  0.317430
# 26  3.126645 -0.218167
# 27  3.125982  0.022071
# 28  3.116427  0.295573
# 29  3.116583  0.115063
# ..       ...       ...
# 70  3.061639  0.378155
# 71  3.131258  0.115285
# 72  3.129558  0.095406
# 73  3.080491  0.391659
# 74  3.129428 -0.151783
# 75  3.124260 -0.268468
# 76  3.127310  0.150233
# 77  3.130834  0.190290
# 78  3.129371  0.027967
# 79  3.130533 -0.140121
# 80  3.130612  0.064787
# 81  3.127653 -0.151973
# 82  3.048627 -0.410642
# 83  3.095826 -0.334174
# 84  3.129478 -0.076089
# 85  3.125190  0.282184
# 86  3.130945  0.115399
# 87  3.097256  0.322247
# 88  3.101775  0.328586
# 89  3.126899 -0.239389
# 90  3.118196 -0.336048
# 91  3.125008  0.012142
# 92  3.130269 -0.068657
# 93  3.124895  0.146069
# 94  3.109039  0.351381
# 95  3.121204 -0.090744
# 96  3.129028 -0.050448
# 97  3.125088 -0.172387
# 98  3.122212  0.283703
# 99  3.124678  0.064417
#
# [100 rows x 2 columns]

# %%
poses.mean()
# Out:
# r        3.120462
# theta    0.015566
# dtype: float64

# %%
poses.var()
# Out:
# r        0.000216
# theta    0.047725
# dtype: float64

# %%
poses.std()
# Out:
# r        0.014684
# theta    0.218461
# dtype: float64
