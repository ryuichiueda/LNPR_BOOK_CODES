# %%
import sys              ###motion_test_header
sys.path.append('../scripts/')
from robot import *

# %%
import copy

world = World(40.0, 0.1)                    ###motion_test_linear

initial_pose = np.array([0, 0, 0]).T
linear = Agent(0.0, 0.1) 
robots = []
r = Robot(initial_pose, sensor=None, agent=linear) 
for i in range(100):
    copy_r = copy.copy(r)
    copy_r.distance_until_noise = copy_r.noise_pdf.rvs()
    world.append(copy_r)
    robots.append(copy_r)

### アニメーション実行 ###
world.draw()
# Out:
# <img src="data:image/png;base64,..." width="400">

# %%
import pandas as pd ###motion_test_stats（下のセルまで。データは上の5行程度を掲載）
poses = pd.DataFrame([ [math.sqrt(r.pose[0]**2 + r.pose[1]**2), r.pose[2]] for r in robots], columns=['r', 'theta'])
poses
# Out:
#       r     theta
# 0   0.0  4.584679
# 1   0.0  4.519586
# 2   0.0  4.549723
# 3   0.0  4.440488
# 4   0.0  4.746209
# 5   0.0  4.532221
# 6   0.0  4.478626
# 7   0.0  4.527200
# 8   0.0  4.440657
# 9   0.0  4.443567
# 10  0.0  4.661685
# 11  0.0  4.623315
# 12  0.0  4.461164
# 13  0.0  4.800240
# 14  0.0  4.665417
# 15  0.0  4.550853
# 16  0.0  4.662656
# 17  0.0  4.666966
# 18  0.0  4.675460
# 19  0.0  4.473567
# 20  0.0  4.560869
# 21  0.0  4.576099
# 22  0.0  4.520344
# 23  0.0  4.509680
# 24  0.0  4.564584
# 25  0.0  4.434076
# 26  0.0  4.539461
# 27  0.0  4.768493
# 28  0.0  4.249624
# 29  0.0  4.646231
# ..  ...       ...
# 70  0.0  4.616599
# 71  0.0  4.661943
# 72  0.0  4.743038
# 73  0.0  4.591224
# 74  0.0  4.648673
# 75  0.0  4.751008
# 76  0.0  4.624065
# 77  0.0  4.530144
# 78  0.0  4.561787
# 79  0.0  4.586309
# 80  0.0  4.509488
# 81  0.0  4.668188
# 82  0.0  4.473507
# 83  0.0  4.445545
# 84  0.0  4.527928
# 85  0.0  4.718861
# 86  0.0  4.487758
# 87  0.0  4.779713
# 88  0.0  4.604228
# 89  0.0  4.717676
# 90  0.0  4.517693
# 91  0.0  4.440163
# 92  0.0  4.666272
# 93  0.0  4.477468
# 94  0.0  4.566532
# 95  0.0  4.464658
# 96  0.0  4.481590
# 97  0.0  4.606624
# 98  0.0  4.504320
# 99  0.0  4.586854
#
# [100 rows x 2 columns]

# %%
poses.mean()
# Out:
# r        0.000000
# theta    4.600183
# dtype: float64

# %%
poses.var()
# Out:
# r        0.000000
# theta    0.012403
# dtype: float64

# %%
poses.std()
# Out:
# r        0.00000
# theta    0.11137
# dtype: float64

# %%
0.012403/4.600183
# Out:
# 0.002696197086072445
