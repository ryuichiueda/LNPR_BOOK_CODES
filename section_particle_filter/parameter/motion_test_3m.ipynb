# %%
import sys              ###motion_test_header
sys.path.append('../scripts/')
from robot import *

# %%
world = World(30.0, 0.1)                    ###motion_test_linear

initial_pose = np.array([0, 0, 0]).T
linear = Agent(0.1, 0.0) 
robots = []
for i in range(100):
    r = Robot(initial_pose, sensor=None, agent=linear) 
    world.append(r)
    robots.append(r)

### アニメーション実行 ###
world.draw()
# Out:
# <img src="data:image/png;base64,..." width="400">

# %%
import pandas as pd ###motion_test_stats（下のセルまで。データは上の5行程度を掲載）
poses = pd.DataFrame([ [math.sqrt(r.pose[0]**2 + r.pose[1]**2), r.pose[2]] for r in robots], columns=['r', 'theta'])
poses
# Out:
#            r     theta
# 0   2.438753 -0.077431
# 1   2.443388  0.146731
# 2   2.865306  0.198832
# 3   3.125165 -0.164361
# 4   3.163013 -0.120595
# 5   2.523444  0.127465
# 6   2.650121 -0.206344
# 7   3.807516 -0.222277
# 8   2.622222 -0.493298
# 9   2.812887 -0.154076
# 10  2.926362  0.018872
# 11  3.120028 -0.182307
# 12  2.933044  0.100236
# 13  2.849377 -0.047220
# 14  2.824439 -0.085798
# 15  2.998167 -0.047634
# 16  3.123713  0.230052
# 17  2.676380  0.089040
# 18  2.977138 -0.201298
# 19  2.843382  0.117933
# 20  3.123597  0.252144
# 21  3.399593  0.243222
# 22  2.890457 -0.156233
# 23  2.858178 -0.010641
# 24  2.466420 -0.104777
# 25  3.335237 -0.204765
# 26  3.235155 -0.103538
# 27  3.158083  0.199564
# 28  2.927455  0.080381
# 29  3.062201 -0.076733
# ..       ...       ...
# 70  3.173348 -0.139132
# 71  3.150389 -0.130458
# 72  3.199293  0.002733
# 73  3.680262 -0.304793
# 74  2.807890  0.040341
# 75  2.752286  0.353697
# 76  2.736315 -0.405422
# 77  2.549280  0.059375
# 78  2.684861 -0.250530
# 79  2.774212 -0.100697
# 80  3.016238 -0.414603
# 81  2.675295  0.201815
# 82  2.992107 -0.086086
# 83  3.265166 -0.139184
# 84  2.761896  0.361088
# 85  3.252287  0.427819
# 86  2.842582  0.272202
# 87  2.907805 -0.158059
# 88  3.060326  0.041265
# 89  2.793830  0.088951
# 90  2.995153 -0.214033
# 91  3.017063 -0.071781
# 92  2.358439 -0.150427
# 93  3.004144 -0.199653
# 94  3.529198 -0.061113
# 95  3.007774 -0.034548
# 96  3.260765 -0.120696
# 97  2.223790 -0.156027
# 98  2.785711 -0.245526
# 99  3.068049  0.196464
#
# [100 rows x 2 columns]

# %%
poses.mean()
# Out:
# r        2.971303
# theta   -0.027425
# dtype: float64

# %%
poses.var()
# Out:
# r        0.090721
# theta    0.034150
# dtype: float64

# %%
poses.std()
# Out:
# r        0.301199
# theta    0.184798
# dtype: float64

# %%
0.174227/3.14*180
# Out:
# 9.987535031847132

# %%
0.015525 / 3.141592 * 180
# Out:
# 0.8895171619993939
