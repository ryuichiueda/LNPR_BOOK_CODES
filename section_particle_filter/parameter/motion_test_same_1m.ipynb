# %%
import sys              ###motion_test_header
sys.path.append('../scripts/')
from robot import *

# %%
import copy

world = World(10.0, 0.1)                    ###motion_test_linear

initial_pose = np.array([0, 0, 0]).T
linear = Agent(0.1, 0.0) 
robots = []
r = Robot(initial_pose, sensor=None, agent=linear) 
for i in range(100):
    copy_r = copy.copy(r)
    world.append(copy_r)
    robots.append(copy_r)

### アニメーション実行 ###
world.draw()
# Out:
# <img src="data:image/png;base64,..." width="400">

# %%
import pandas as pd ###motion_test_stats（下のセルまで。データは上の5行程度を掲載）
poses = pd.DataFrame([ [math.sqrt(r.pose[0]**2 + r.pose[1]**2), r.pose[2]] for r in robots], columns=['r', 'theta'])
poses
# Out:
#            r     theta
# 0   1.084978 -0.169774
# 1   1.085922  0.067138
# 2   1.086740 -0.016710
# 3   1.085860  0.100174
# 4   1.086157  0.054890
# 5   1.084843 -0.155265
# 6   1.085732  0.050854
# 7   1.086838 -0.021102
# 8   1.085657  0.093770
# 9   1.086605  0.087953
# 10  1.085550 -0.151287
# 11  1.086303  0.051883
# 12  1.086527 -0.077761
# 13  1.086412 -0.072781
# 14  1.086428 -0.012104
# 15  1.085382 -0.127068
# 16  1.086779  0.041792
# 17  1.086126  0.094776
# 18  1.085115 -0.116476
# 19  1.086091 -0.088227
# 20  1.086319 -0.075565
# 21  1.086173 -0.055671
# 22  1.085828 -0.052546
# 23  1.085831 -0.178520
# 24  1.086651  0.061436
# 25  1.084202 -0.202688
# 26  1.086476  0.027751
# 27  1.084517 -0.198991
# 28  1.086448  0.081732
# 29  1.078671 -0.301730
# ..       ...       ...
# 70  1.085737  0.013680
# 71  1.084560  0.131998
# 72  1.086082  0.101048
# 73  1.086420  0.091189
# 74  1.086047  0.068499
# 75  1.086684  0.049003
# 76  1.086271  0.037347
# 77  1.086748  0.024116
# 78  1.084510  0.163682
# 79  1.083703 -0.222347
# 80  1.082535  0.188744
# 81  1.079949  0.213933
# 82  1.080123  0.205027
# 83  1.086407 -0.058236
# 84  1.085342  0.022828
# 85  1.085869  0.105764
# 86  1.086432 -0.082341
# 87  1.085798 -0.087979
# 88  1.085764 -0.105953
# 89  1.086417  0.076242
# 90  1.085514 -0.118028
# 91  1.085654 -0.086876
# 92  1.086636  0.106209
# 93  1.086245 -0.003820
# 94  1.085471  0.069018
# 95  1.082771 -0.217087
# 96  1.086367 -0.043465
# 97  1.086679  0.051358
# 98  1.086627 -0.006839
# 99  1.084665  0.159193
#
# [100 rows x 2 columns]

# %%
poses.mean()
# Out:
# r        1.085387
# theta   -0.009112
# dtype: float64

# %%
poses.var()
# Out:
# r        0.000004
# theta    0.014728
# dtype: float64

# %%
poses.std()
# Out:
# r        0.001880
# theta    0.121359
# dtype: float64
