# %%
import sys     ###motion_test_header
sys.path.append('../scripts/')
from robot import *

# %%
import copy    ###motion_test_linear

world = World(40.0, 0.1)  

initial_pose = np.array([0, 0, 0]).T
robots = []
r = Robot(initial_pose, sensor=None, agent=Agent(0.0, 0.1)) 

for i in range(100):
    copy_r = copy.copy(r)
    copy_r.distance_until_noise = copy_r.noise_pdf.rvs()
    world.append(copy_r)
    robots.append(copy_r)

world.draw()
# Out:
# <img src="data:image/png;base64,..." width="400">

# %%
import pandas as pd ###motion_test_stats_rot
poses = pd.DataFrame([ [math.sqrt(r.pose[0]**2 + r.pose[1]**2), r.pose[2]] for r in robots], columns=['r', 'theta'])
poses.transpose()
# Out:
#              0         1         2         3         4        5         6   \
# r      0.000000  0.000000  0.000000  0.000000  0.000000  0.00000  0.000000
# theta  4.481115  4.519823  4.316018  4.215649  4.099438  4.33411  4.290798
#
#              7         8         9     ...           90       91        92  \
# r      0.000000  0.000000  0.000000    ...     0.000000  0.00000  0.000000
# theta  4.268664  4.291169  4.476318    ...     4.366825  4.34318  4.314661
#
#              93        94        95       96        97        98        99
# r      0.000000  0.000000  0.000000  0.00000  0.000000  0.000000  0.000000
# theta  4.275099  4.192354  4.248579  4.24372  4.221952  4.187682  4.387461
#
# [2 rows x 100 columns]

# %%
print(poses["theta"].var())
print(poses["theta"].mean())
math.sqrt(poses["theta"].var()/poses["theta"].mean())
# Out:
# 0.009815619152382002
# 4.309863011626852
# 0.04772293183402449
