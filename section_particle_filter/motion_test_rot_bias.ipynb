# %%
import sys     ###motion_test_header
sys.path.append('../scripts/')
from robot import *

# %%
world = World(40.0, 0.1)  

initial_pose = np.array([0, 0, 0]).T
robots = []

for i in range(100):
    r = Robot(initial_pose, sensor=None, agent=Agent(0.0, 0.1)) 
    world.append(r)
    robots.append(r)

world.draw()
# Out:
# <img src="data:image/png;base64,..." width="400">

# %%
import pandas as pd ###motion_test_stats_rot
poses = pd.DataFrame([ [math.sqrt(r.pose[0]**2 + r.pose[1]**2), r.pose[2]] for r in robots], columns=['r', 'theta'])
poses.transpose()
# Out:
#              0         1         2         3       4         5         6   \
# r      0.000000  0.000000  0.000000  0.000000  0.0000  0.000000  0.000000
# theta  4.398445  3.690387  4.078043  3.716504  4.0419  3.198651  3.873169
#
#              7         8         9     ...           90        91        92  \
# r      0.000000  0.000000  0.000000    ...     0.000000  0.000000  0.000000
# theta  4.272651  4.516073  4.675161    ...     3.560867  4.081433  3.962668
#
#              93        94       95       96        97        98        99
# r      0.000000  0.000000  0.00000  0.00000  0.000000  0.000000  0.000000
# theta  3.565343  3.751608  3.86375  4.05755  3.947848  3.330153  3.633212
#
# [2 rows x 100 columns]

# %%
print(poses["theta"].var())
print(poses["theta"].mean())
math.sqrt(poses["theta"].var()/poses["theta"].mean())
# Out:
# 0.10926368187845754
# 4.011578527689154
# 0.16503659942823132
