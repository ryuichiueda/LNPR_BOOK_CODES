# %%
v = {}
for line in open("/Users/ueda/GIT/LoPR_BOOK/reinforcement_learning_results/sarsa_lambda1_value2000000.txt", "r"):
    d = line.split()
    v[ (int(d[0]), int(d[1]), int(d[2]))] = float(d[3])

# %%
import sys ###dppolicyagent
sys.path.append('../scripts/')
from puddle_world import *

# %%
xy = np.zeros((40,40))
for x in range(40):
    for y in range(40):
        xy[x,y] = v[(x,y,18)]
        
import seaborn as sns   
sns.heatmap(np.rot90(xy), square=False)
plt.show()
# Out:
# <img src="data:image/png;base64,..." width="640">
