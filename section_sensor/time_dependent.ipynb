# %%
import pandas as pd
import numpy as np
import seaborn as sns
import matplotlib.pyplot as plt

data  = pd.read_csv("sensor_data_200.txt", delimiter=" ", 
                    header=None, names = ("date","time","ir","lidar"))

###計測値の先頭のデータを除去して後ろにくっつけ、
###ある計測値の次の計測値のリストを作ってデータフレームに追加
data["irnext"] = np.append(data.ir.values[1:], data.ir.values[0]) 
data["lidarnext"] = np.append(data.lidar.values[1:], data.lidar.values[0])

data
# Out:
#            date    time   ir  lidar  irnext  lidarnext
# 0      20180122   95819  305    214     299        211
# 1      20180122   95822  299    211     292        199
# 2      20180122   95826  292    199     321        208
# 3      20180122   95829  321    208     298        212
# 4      20180122   95832  298    212     327        212
# 5      20180122   95835  327    212     293        215
# 6      20180122   95838  293    215     309        218
# 7      20180122   95840  309    218     323        208
# 8      20180122   95843  323    208     292        217
# 9      20180122   95846  292    217     294        215
# 10     20180122   95850  294    215     323        218
# 11     20180122   95852  323    218     319        218
# 12     20180122   95856  319    218     313        214
# 13     20180122   95858  313    214     298        209
# 14     20180122   95902  298    209     296        211
# 15     20180122   95905  296    211     294        210
# 16     20180122   95908  294    210     314        215
# 17     20180122   95911  314    215     300        212
# 18     20180122   95914  300    212     324        219
# 19     20180122   95917  324    219     295        220
# 20     20180122   95920  295    220     320        214
# 21     20180122   95922  320    214     302        211
# 22     20180122   95925  302    211     303        215
# 23     20180122   95928  303    215     297        215
# 24     20180122   95932  297    215     306        210
# 25     20180122   95934  306    210     302        217
# 26     20180122   95937  302    217     296        215
# 27     20180122   95940  296    215     308        213
# 28     20180122   95943  308    213     303        211
# 29     20180122   95947  303    211     309        215
# ...         ...     ...  ...    ...     ...        ...
# 58958  20180124  115907  297    210     320        204
# 58959  20180124  115910  320    204     324        205
# 58960  20180124  115914  324    205     302        199
# 58961  20180124  115917  302    199     299        203
# 58962  20180124  115919  299    203     298        206
# 58963  20180124  115923  298    206     301        206
# 58964  20180124  115925  301    206     321        206
# 58965  20180124  115929  321    206     319        209
# 58966  20180124  115932  319    209     311        208
# 58967  20180124  115935  311    208     326        204
# 58968  20180124  115938  326    204     319        206
# 58969  20180124  115941  319    206     303        201
# 58970  20180124  115944  303    201     323        203
# 58971  20180124  115947  323    203     302        205
# 58972  20180124  115950  302    205     314        202
# 58973  20180124  115953  314    202     326        204
# 58974  20180124  115956  326    204     308        201
# 58975  20180124  115959  308    201     302        209
# 58976  20180124  120002  302    209     303        207
# 58977  20180124  120005  303    207     310        206
# 58978  20180124  120009  310    206     330        208
# 58979  20180124  120012  330    208     305        205
# 58980  20180124  120015  305    205     301        202
# 58981  20180124  120018  301    202     320        206
# 58982  20180124  120021  320    206     313        208
# 58983  20180124  120023  313    208     297        200
# 58984  20180124  120026  297    200     323        204
# 58985  20180124  120030  323    204     326        207
# 58986  20180124  120033  326    207     321        208
# 58987  20180124  120036  321    208     305        214
#
# [58988 rows x 6 columns]

# %%
sns.jointplot(data["lidar"], data["lidarnext"], data, kind="kde") ###lidarcor###
plt.show()

# %%
d = data[ (data["time"] < 120000) & (data["time"] >= 113000) ]

sns.jointplot(d["lidar"], d["lidarnext"], d, kind="kde")
plt.show()

# %%
d = data[ (data["time"] < 120000) & (data["time"] >= 113000) ]

sns.jointplot(d["ir"], d["irnext"], d, kind="kde")
plt.show()
