# %%
mean = 209.7
var = 23.4

p = 1 - var / mean
n = mean / p
p, n
# Out:
# (0.8884120171673819, 236.0391304347826)

# %%
import matplotlib.pyplot as plt
from scipy.stats import binom
xs = range(190,230)
ys = binom(n,p).pmf(xs)
plt.plot(xs,ys)
plt.show()
