# %% [markdown]
# # ノートの例

# %%
# %matplotlib inline
import matplotlib.pyplot as plt                      ### notebook_sample ###
plt.plot([1,2,3],[4,5,6])

# %% [markdown]
# ## 数式
#
# TeXの数式が使えます。

# %% [markdown]
# $y = \dfrac{\log x^2}{\sin z}$
